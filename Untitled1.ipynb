# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_selection import RFE
import joblib

# %%
df = pd.read_csv("nursery.csv")

df
# Out:
#           parents   has_nurs      form children     housing     finance  \
# 0           usual     proper  complete        1  convenient  convenient
# 1           usual     proper  complete        1  convenient  convenient
# 2           usual     proper  complete        1  convenient  convenient
# 3           usual     proper  complete        1  convenient  convenient
# 4           usual     proper  complete        1  convenient  convenient
# ...           ...        ...       ...      ...         ...         ...
# 12955  great_pret  very_crit    foster     more    critical      inconv
# 12956  great_pret  very_crit    foster     more    critical      inconv
# 12957  great_pret  very_crit    foster     more    critical      inconv
# 12958  great_pret  very_crit    foster     more    critical      inconv
# 12959  great_pret  very_crit    foster     more    critical      inconv
#
#               social       health      Target
# 0            nonprob  recommended   recommend
# ...

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12960 entries, 0 to 12959
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0    parents  12960 non-null  object
#  1   has_nurs  12960 non-null  object
#  2   form      12960 non-null  object
#  3   children  12960 non-null  object
#  4   housing   12960 non-null  object
#  5   finance   12960 non-null  object
#  6   social    12960 non-null  object
#  7   health    12960 non-null  object
#  8   Target    12960 non-null  object
# dtypes: object(9)
# memory usage: 911.4+ KB
# None
#         parents has_nurs      form children     housing     finance   social  \
# count     12960    12960     12960    12960       12960       12960    12960
# unique        3        5         4        4           3           2        3
# top       usual   proper  complete        1  convenient  convenient  nonprob
# ...

# %%
color = plt.get_cmap("tab20").colors
fig, axes = plt.subplots(4, 2, figsize=(16, 23))
categories = df.columns.tolist()[:8]
for i in range(4):
    for j in range(2):
        feature = categories[i * 2 + j]
        count = df[feature].value_counts()
        
        wedges, texts, autotexts = axes[i, j].pie(
            count, 
            autopct='%1.1f%%', 
            colors=color, 
            startangle=140, 
            wedgeprops={'edgecolor': 'black'}
        )
        
        axes[i, j].set_title(f"Distribution of {feature}", fontsize=18, weight='bold')
        
        for autotext in autotexts:
            autotext.set_color('white')
            autotext.set_fontsize(15)
            autotext.set_weight('bold')
        
        for text in texts:
            text.set_fontsize(12)
            text.set_weight('bold')
        
        axes[i, j].axis('equal')
        
        axes[i, j].legend(
            wedges, 
            count.index, 
            title="Categories", 
            loc="center left", 
            bbox_to_anchor=(1, 0, 0, 1),
            prop={"size": 16}
            )
plt.tight_layout()
plt.show()

# %%
label_encoder = LabelEncoder()
df_encoded = df.copy()
features = df_encoded.select_dtypes(include="object").columns
for feature in features[:8]:
    df_encoded[feature] = label_encoder.fit_transform(df_encoded[feature])
df_encoded["children"] += 1
df_encoded
# Out:
#         parents  has_nurs  form  children  housing  finance  social  health  \
# 0             2         3     0         1        0        0       0       2
# 1             2         3     0         1        0        0       0       1
# 2             2         3     0         1        0        0       0       0
# 3             2         3     0         1        0        0       2       2
# 4             2         3     0         1        0        0       2       1
# ...         ...       ...   ...       ...      ...      ...     ...     ...
# 12955         0         4     2         4        1        1       2       1
# 12956         0         4     2         4        1        1       2       0
# 12957         0         4     2         4        1        1       1       2
# 12958         0         4     2         4        1        1       1       1
# 12959         0         4     2         4        1        1       1       0
#
#            Target
# 0       recommend
# ...

# %%
X = df_encoded.iloc[:, :8]
y = df_encoded["Target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
logistic_reg = RFE(LogisticRegression(max_iter=1000), n_features_to_select=2).fit(X_train, y_train)
y_pred_logistic = logistic_reg.predict(X_test)
print("Logistic_reg", accuracy_score(y_pred_logistic, y_test))
# Out:
# Logistic_reg 0.7628600823045267

# %%
random_forest = RFE(RandomForestClassifier(), n_features_to_select=8).fit(X_train, y_train)
y_pred_forest = random_forest.predict(X_test)
print("Random_forest", accuracy_score(y_pred_forest, y_test))
# Out:
# Random_forest 0.9804526748971193

# %%
decision_tree = DecisionTreeClassifier().fit(X_train, y_train)
y_pred_decision = decision_tree.predict(X_test)
print("Decision_tree", accuracy_score(y_pred_decision, y_test))
# Out:
# Decision_tree 0.992798353909465

# %%
K_neighbor = KNeighborsClassifier().fit(X_train, y_train)
y_pred_kneighbor = K_neighbor.predict(X_test)
print("K_neighbor", accuracy_score(y_pred_kneighbor, y_test))
# Out:
# K_neighbor 0.9405864197530864

# %%
print("Logistic_regression: ", classification_report(y_test, y_pred_logistic, zero_division=1))
print("Random_forest: ", classification_report(y_test, y_pred_forest, zero_division=1))
print("Decision_tree: ", classification_report(y_test, y_pred_decision, zero_division=1))
print("Kneighbors: ", classification_report(y_test, y_pred_kneighbor, zero_division=1))
# Out:
# Logistic_regression:                precision    recall  f1-score   support
#
#    not_recom       1.00      1.00      1.00      1320
#     priority       0.64      0.64      0.64      1272
#    recommend       1.00      0.00      0.00         2
#   spec_prior       0.64      0.70      0.67      1190
#   very_recom       1.00      0.00      0.00       104
#
#     accuracy                           0.76      3888
#    macro avg       0.86      0.47      0.46      3888
# weighted avg       0.77      0.76      0.75      3888
#
# Random_forest:                precision    recall  f1-score   support
#
#    not_recom       1.00      1.00      1.00      1320
#     priority       0.97      0.98      0.97      1272
#    recommend       1.00      0.00      0.00         2
#   spec_prior       0.98      0.98      0.98      1190
#   very_recom       0.97      0.75      0.85       104
#
#     accuracy                           0.98      3888
#    macro avg       0.98      0.74      0.76      3888
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
logistic = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_logistic))
random = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_forest))
decision = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_decision))
Kneighbor = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_kneighbor))
logistic.plot(cmap="Reds", ax=axes[0,0], values_format="d")
random.plot(cmap="Blues", ax=axes[0,1], values_format="d")
decision.plot(cmap="Greens", ax=axes[1,0], values_format="d")
Kneighbor.plot(cmap="Oranges", ax=axes[1,1], values_format="d")
axes[0,0].set_title("Logistic Regression")
axes[0,1].set_title("Random Forest")
axes[1,0].set_title("Decision Tree")
axes[1,1].set_title("K_Neighbors")
fig.set_edgecolor("black")
plt.tight_layout()
plt.show()

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}
grid_search = GridSearchCV(estimator=decision_tree, param_grid=param_grid, cv=3, n_jobs=1, scoring="accuracy")
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
Decision_tree_best = DecisionTreeClassifier(
    criterion=best_params["criterion"],
    max_depth=best_params["max_depth"],
    max_features=best_params["max_features"],
    min_samples_leaf=best_params["min_samples_leaf"],
    min_samples_split=best_params["min_samples_split"],
    splitter=best_params["splitter"]
)


Decision_tree_best.fit(X_train, y_train)
y_pred_best = Decision_tree_best.predict(X_test)
print(classification_report(y_test, y_pred_best, zero_division=1))
print(accuracy_score(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#    not_recom       1.00      1.00      1.00      1320
#     priority       0.99      0.99      0.99      1272
#    recommend       1.00      0.00      0.00         2
#   spec_prior       1.00      0.99      0.99      1190
#   very_recom       0.94      1.00      0.97       104
#
#     accuracy                           0.99      3888
#    macro avg       0.98      0.80      0.79      3888
# weighted avg       0.99      0.99      0.99      3888
#
# 0.9940843621399177

# %%
joblib.dump(Decision_tree_best,"Project_Model.pkl")
# Out:
# ['Project_Model.pkl']
